# %% [markdown]
# # Analyse population Humaine

# %%
#import modules
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from functools import reduce
import numpy as np
from tools import calPopMaleFemale

# %%
# Load dataset
df = pd.read_csv('Data/PopulationByAgeSex.csv', index_col="Time", parse_dates=True)
print(df.shape)
print(df['PopMale_0_4'].sum())
df.head(10)
# Out:
# (66893, 70)
# 1904302820.743
#             Id  LocID     Location  PopMale_0_4  PopFemale_0_4  PopTotal_0_4  \
# Time
# 1950-01-01   1      4  Afghanistan      630.044        661.578      1291.622
# 1951-01-01   2      4  Afghanistan      641.199        673.293      1314.492
# 1952-01-01   3      4  Afghanistan      650.825        669.274      1320.099
# 1953-01-01   4      4  Afghanistan      659.896        663.606      1323.502
# 1954-01-01   5      4  Afghanistan      670.694        663.295      1333.989
# 1955-01-01   6      4  Afghanistan      685.797        671.613      1357.410
# 1956-01-01   7      4  Afghanistan      708.815        678.490      1387.305
# 1957-01-01   8      4  Afghanistan      727.044        693.963      1421.007
# 1958-01-01   9      4  Afghanistan      743.089        714.746      1457.835
# 1959-01-01  10      4  Afghanistan      759.830        737.536      1497.366
#
#             PopMale_5_9  PopFemale_5_9  PopTotal_5_9  PopMale_10_14  ...  \
# ...

# %%
# see the id location
locID = df['LocID'].unique()
print(f'le shape des LocD: {locID.shape}')
print(locID)
# Out:
# le shape des LocD: (443,)
# [   4  903 1823 1560 2080 2081 2082 2083 2084 1200    8   12 1533   24
#    28   32   51  533  935 1207 1824 1557   36  927   40   31 1525 1526
#    44   48   50   52  112   56   84 2067 2068 2069 2070 2071 2072  204
#    64 1527 1569   68   70   72   76   96  100  854  108  132  116  120
#   124  915 1530  140  916 5500 1545  921  148  830  152  156 1105  344
#   446  158  170 1566 2074 2075 2076 2077 2078 2079  174  178  188 1638
#  2094 2095 2096 2097 2098 2099  191  192  531  196  203  384  408  180
#   208 1106  262  214 1737 1736 1744 1746 1071 1074 1075 1073 1072 2061
#  2058 2059 2060 1054 1057 1055 2049 1060 1059 1058 1056 2048 2045 2046
#  2047 2044 2053 1064 2054 2050 1062 2051 2055 1065 2052 2056 2062 2066
#  2065 2063 2064 1765 1563  910  906  923 1825 1832 1538 1540 1547  218
#   818  222  226  232  233  748  231 1546  908  917 1506 1829 1550 1544
#  1549  986  242  246  250 1107  254  258  266  270  268  276  288 1536
# ...

# %%
#see all location
location = df['Location'].unique()
print(f'le noms des nation et organisation: {location.shape}')
print(location)
# Out:
# le noms des nation et organisation: (440,)
# ['Afghanistan' 'Africa' 'African Group' 'African Union'
#  'African Union: Central Africa' 'African Union: Eastern Africa'
#  'African Union: Northern Africa' 'African Union: Southern Africa'
#  'African Union: Western Africa'
#  'African; Caribbean and Pacific (ACP) Group of States' 'Albania'
#  'Algeria' 'Andean Community' 'Angola' 'Antigua and Barbuda' 'Argentina'
#  'Armenia' 'Aruba' 'Asia' 'Asia-Pacific Economic Cooperation (APEC)'
#  'Asia-Pacific Group' 'Association of Southeast Asian Nations (ASEAN)'
#  'Australia' 'Australia/New Zealand' 'Austria' 'Azerbaijan' 'BRIC' 'BRICS'
#  'Bahamas' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus' 'Belgium' 'Belize'
#  'Belt-Road Initiative (BRI)' 'Belt-Road Initiative: Africa'
#  'Belt-Road Initiative: Asia' 'Belt-Road Initiative: Europe'
#  'Belt-Road Initiative: Latin America and the Caribbean'
#  'Belt-Road Initiative: Pacific' 'Benin' 'Bhutan'
#  'Black Sea Economic Cooperation (BSEC)'
# ...

# %%
# number of location total
print(f"Le nombre de nations: {len(location)}")
# Out:
# Le nombre de nations: 440

# %% [markdown]
# # Etudes de la population mondiale

# %%
#Population male:
popMale = df[df["LocID"]==4]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==4]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==4]['PopTotal']

#names countries
popCountry = df[df["LocID"]==4]["Location"].unique()

# %%
#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)
# Out:
# ['Afghanistan']
# Graph de la population masculine et femine et mondiale:
#              PopMale  PopFemale
# Time
# 1950-01-01  4099.243   3652.874
# 1951-01-01  4134.756   3705.395
# 1952-01-01  4174.450   3761.546
# 1953-01-01  4218.336   3821.348
# 1954-01-01  4266.484   3884.832

# %%
#Population male:
popMale = df[df["LocID"]==903]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==903]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==903]['PopTotal']

#names countries
popCountry = df[df["LocID"]==903]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)
# Out:
# ['Africa']
# Graph de la population masculine et femine et mondiale:
#                PopMale   PopFemale
# Time
# 1950-01-01  113209.034  114585.103
# 1951-01-01  115442.706  116885.151
# 1952-01-01  117800.711  119295.849
# 1953-01-01  120282.468  121809.988
# 1954-01-01  122887.064  124423.533

# %%
#Population male:
popMale = df[df["LocID"]==1823]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1823]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1823]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1823]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1560]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1560]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1560]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1560]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2080]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2080]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2080]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2080]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2081]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2081]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2081]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2081]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2083]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2083]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2083]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2083]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2084]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2084]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2084]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2084]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1200]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1200]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1200]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1200]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==8]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==8]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==8]['PopTotal']

#names countries
popCountry = df[df["LocID"]==8]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==12]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==12]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==12]['PopTotal']

#names countries
popCountry = df[df["LocID"]==12]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1533]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1533]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1533]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1533]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==24]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==24]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==24]['PopTotal']

#names countries
popCountry = df[df["LocID"]==24]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==28]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==28]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==28]['PopTotal']

#names countries
popCountry = df[df["LocID"]==28]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==32]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==32]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==32]['PopTotal']

#names countries
popCountry = df[df["LocID"]==32]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==51]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==51]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==51]['PopTotal']

#names countries
popCountry = df[df["LocID"]==51]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==533]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==533]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==533]['PopTotal']

#names countries
popCountry = df[df["LocID"]==533]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==935]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==935]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==935]['PopTotal']

#names countries
popCountry = df[df["LocID"]==935]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1207]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1207]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1207]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1207]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1824]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1824]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1824]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1824]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1557]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1557]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1557]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1557]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==36]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==36]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==36]['PopTotal']

#names countries
popCountry = df[df["LocID"]==36]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==927]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==927]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==927]['PopTotal']

#names countries
popCountry = df[df["LocID"]==927]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==40]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==40]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==40]['PopTotal']

#names countries
popCountry = df[df["LocID"]==40]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==31]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==31]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==31]['PopTotal']

#names countries
popCountry = df[df["LocID"]==31]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1525]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1525]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1525]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1525]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1526]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1526]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1526]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1526]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==44]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==44]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==44]['PopTotal']

#names countries
popCountry = df[df["LocID"]==44]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==48]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==48]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==48]['PopTotal']

#names countries
popCountry = df[df["LocID"]==48]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==50]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==50]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==50]['PopTotal']

#names countries
popCountry = df[df["LocID"]==50]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==52]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==52]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==52]['PopTotal']

#names countries
popCountry = df[df["LocID"]==52]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==112]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==112]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==112]['PopTotal']

#names countries
popCountry = df[df["LocID"]==112]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==56]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==56]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==56]['PopTotal']

#names countries
popCountry = df[df["LocID"]==56]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==84]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==84]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==84]['PopTotal']

#names countries
popCountry = df[df["LocID"]==84]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2067]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2067]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2067]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2067]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2068]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2068]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2068]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2068]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2069]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2069]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2069]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2069]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2070]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2070]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2070]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2070]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2071]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2071]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2071]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2071]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2072]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2072]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2072]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2072]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==204]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==204]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==204]['PopTotal']

#names countries
popCountry = df[df["LocID"]==204]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==64]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==64]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==64]['PopTotal']

#names countries
popCountry = df[df["LocID"]==64]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1527]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1527]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1527]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1527]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1569]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1569]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1569]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1569]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==68]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==68]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==68]['PopTotal']

#names countries
popCountry = df[df["LocID"]==68]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==70]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==70]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==70]['PopTotal']

#names countries
popCountry = df[df["LocID"]==70]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==72]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==72]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==72]['PopTotal']

#names countries
popCountry = df[df["LocID"]==72]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==76]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==76]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==76]['PopTotal']

#names countries
popCountry = df[df["LocID"]==76]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==96]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==96]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==96]['PopTotal']

#names countries
popCountry = df[df["LocID"]==96]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==100]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==100]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==100]['PopTotal']

#names countries
popCountry = df[df["LocID"]==100]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==854]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==854]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==854]['PopTotal']

#names countries
popCountry = df[df["LocID"]==854]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==108]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==108]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==108]['PopTotal']

#names countries
popCountry = df[df["LocID"]==108]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==132]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==132]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==132]['PopTotal']

#names countries
popCountry = df[df["LocID"]==132]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==116]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==116]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==116]['PopTotal']

#names countries
popCountry = df[df["LocID"]==116]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==120]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==120]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==120]['PopTotal']

#names countries
popCountry = df[df["LocID"]==120]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==124]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==124]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==124]['PopTotal']

#names countries
popCountry = df[df["LocID"]==124]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==915]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==915]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==915]['PopTotal']

#names countries
popCountry = df[df["LocID"]==915]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1530]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1530]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1530]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1530]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==140]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==140]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==140]['PopTotal']

#names countries
popCountry = df[df["LocID"]==140]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==916]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==916]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==916]['PopTotal']

#names countries
popCountry = df[df["LocID"]==916]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==5500]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==5500]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==5500]['PopTotal']

#names countries
popCountry = df[df["LocID"]==5500]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1545]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1545]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1545]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1545]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==921]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==921]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==921]['PopTotal']

#names countries
popCountry = df[df["LocID"]==921]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==148]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==148]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==148]['PopTotal']

#names countries
popCountry = df[df["LocID"]==148]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==830]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==830]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==830]['PopTotal']

#names countries
popCountry = df[df["LocID"]==830]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==152]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==152]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==152]['PopTotal']

#names countries
popCountry = df[df["LocID"]==152]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==156]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==156]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==156]['PopTotal']

#names countries
popCountry = df[df["LocID"]==156]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1105]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1105]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1105]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1105]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==344]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==344]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==344]['PopTotal']

#names countries
popCountry = df[df["LocID"]==344]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==446]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==446]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==446]['PopTotal']

#names countries
popCountry = df[df["LocID"]==446]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==158]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==158]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==158]['PopTotal']

#names countries
popCountry = df[df["LocID"]==158]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==170]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==170]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==170]['PopTotal']

#names countries
popCountry = df[df["LocID"]==170]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1566]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1566]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1566]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1566]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2074]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2074]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2074]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2074]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2075]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2075]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2075]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2075]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2076]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2076]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2076]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2076]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2077]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2077]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2077]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2077]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2078]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2078]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2078]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2078]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2079]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2079]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2079]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2079]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==174]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==174]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==174]['PopTotal']

#names countries
popCountry = df[df["LocID"]==174]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==178]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==178]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==178]['PopTotal']

#names countries
popCountry = df[df["LocID"]==178]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==188]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==188]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==188]['PopTotal']

#names countries
popCountry = df[df["LocID"]==188]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1638]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1638]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1638]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1638]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2094]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2094]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2094]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2094]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2095]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2095]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2095]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2095]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2096]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2096]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2096]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2096]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2097]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2097]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2097]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2097]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2098]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2098]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2098]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2098]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2099]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2099]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2099]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2099]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==191]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==191]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==191]['PopTotal']

#names countries
popCountry = df[df["LocID"]==191]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==192]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==192]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==192]['PopTotal']

#names countries
popCountry = df[df["LocID"]==192]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==531]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==531]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==531]['PopTotal']

#names countries
popCountry = df[df["LocID"]==531]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==196]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==196]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==196]['PopTotal']

#names countries
popCountry = df[df["LocID"]==196]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==203]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==203]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==203]['PopTotal']

#names countries
popCountry = df[df["LocID"]==203]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==384]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==384]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==384]['PopTotal']

#names countries
popCountry = df[df["LocID"]==384]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==408]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==408]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==408]['PopTotal']

#names countries
popCountry = df[df["LocID"]==408]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==180]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==180]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==180]['PopTotal']

#names countries
popCountry = df[df["LocID"]==180]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==208]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==208]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==208]['PopTotal']

#names countries
popCountry = df[df["LocID"]==208]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1106]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1106]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1106]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1106]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==262]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==262]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==262]['PopTotal']

#names countries
popCountry = df[df["LocID"]==262]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==214]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==214]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==214]['PopTotal']

#names countries
popCountry = df[df["LocID"]==214]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1737]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1737]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1737]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1737]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1736]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1736]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1736]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1736]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1744]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1744]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1744]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1744]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1746]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1746]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1746]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1746]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1071]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1071]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1071]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1071]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1074]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1074]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1074]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1074]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1075]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1075]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1075]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1075]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1073]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1073]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1073]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1073]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1072]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1072]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1072]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1072]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2061]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2061]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2061]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2061]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2058]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2058]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2058]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2058]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2059]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2059]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2059]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2059]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2060]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2060]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2060]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2060]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1054]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1054]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1054]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1054]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1057]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1057]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1057]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1057]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1055]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1055]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1055]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1055]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2049]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2049]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2049]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2049]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1060]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1060]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1060]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1060]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1059]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1059]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1059]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1059]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1058]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1058]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1058]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1058]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1056]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1056]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1056]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1056]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2048]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2048]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2048]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2048]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2045]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2045]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2045]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2045]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2046]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2046]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2046]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2046]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2047]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2047]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2047]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2047]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2044]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2044]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2044]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2044]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2053]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2053]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2053]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2053]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1064]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1064]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1064]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1064]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2054]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2054]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2054]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2054]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2050]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2050]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2050]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2050]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1062]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1062]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1062]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1062]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2051]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2051]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2051]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2051]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2055]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2055]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2055]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2055]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1065]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1065]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1065]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1065]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2052]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2052]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2052]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2052]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2056]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2056]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2056]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2056]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2062]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2062]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2062]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2062]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2066]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2066]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2066]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2066]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2065]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2065]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2065]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2065]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2063]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2063]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2063]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2063]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2064]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2064]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2064]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2064]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1765]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1765]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1765]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1765]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1563]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1563]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1563]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1563]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==910]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==910]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==910]['PopTotal']

#names countries
popCountry = df[df["LocID"]==910]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==906]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==906]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==906]['PopTotal']

#names countries
popCountry = df[df["LocID"]==906]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==923]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==923]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==923]['PopTotal']

#names countries
popCountry = df[df["LocID"]==923]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1825]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1825]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1825]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1825]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1832]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1832]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1832]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1832]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1538]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1538]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1538]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1538]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1540]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1540]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1540]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1540]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1547]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1547]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1547]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1547]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==818]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==818]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==818]['PopTotal']

#names countries
popCountry = df[df["LocID"]==818]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==222]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==222]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==222]['PopTotal']

#names countries
popCountry = df[df["LocID"]==222]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==226]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==226]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==226]['PopTotal']

#names countries
popCountry = df[df["LocID"]==226]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==232]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==232]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==232]['PopTotal']

#names countries
popCountry = df[df["LocID"]==232]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==233]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==233]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==233]['PopTotal']

#names countries
popCountry = df[df["LocID"]==233]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==748]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==748]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==748]['PopTotal']

#names countries
popCountry = df[df["LocID"]==748]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==231]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==231]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==231]['PopTotal']

#names countries
popCountry = df[df["LocID"]==231]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1546]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1546]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1546]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1546]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==908]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==908]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==908]['PopTotal']

#names countries
popCountry = df[df["LocID"]==908]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==917]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==917]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==917]['PopTotal']

#names countries
popCountry = df[df["LocID"]==917]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1506]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1506]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1506]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1506]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1829]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1829]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1829]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1829]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1550]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1550]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1550]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1550]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1544]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1544]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1544]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1544]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1549]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1549]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1549]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1549]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==986]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==986]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==986]['PopTotal']

#names countries
popCountry = df[df["LocID"]==986]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==242]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==242]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==242]['PopTotal']

#names countries
popCountry = df[df["LocID"]==242]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==246]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==246]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==246]['PopTotal']

#names countries
popCountry = df[df["LocID"]==246]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==250]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==250]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==250]['PopTotal']

#names countries
popCountry = df[df["LocID"]==250]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1107]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1107]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1107]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1107]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==254]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==254]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==254]['PopTotal']

#names countries
popCountry = df[df["LocID"]==254]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==258]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==258]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==258]['PopTotal']

#names countries
popCountry = df[df["LocID"]==258]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==266]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==266]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==266]['PopTotal']

#names countries
popCountry = df[df["LocID"]==266]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==270]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==270]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==270]['PopTotal']

#names countries
popCountry = df[df["LocID"]==270]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==268]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==268]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==268]['PopTotal']

#names countries
popCountry = df[df["LocID"]==268]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==276]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==276]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==276]['PopTotal']

#names countries
popCountry = df[df["LocID"]==276]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==288]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==288]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==288]['PopTotal']

#names countries
popCountry = df[df["LocID"]==288]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1536]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1536]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1536]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1536]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==300]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==300]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==300]['PopTotal']

#names countries
popCountry = df[df["LocID"]==300]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==308]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==308]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==308]['PopTotal']

#names countries
popCountry = df[df["LocID"]==308]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1556]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1556]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1556]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1556]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1523]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1523]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1523]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1523]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1522]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1522]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1522]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1522]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1524]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1524]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1524]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1524]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==312]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==312]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==312]['PopTotal']

#names countries
popCountry = df[df["LocID"]==312]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==316]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==316]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==316]['PopTotal']

#names countries
popCountry = df[df["LocID"]==316]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==320]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==320]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==320]['PopTotal']

#names countries
popCountry = df[df["LocID"]==320]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==324]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==324]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==324]['PopTotal']

#names countries
popCountry = df[df["LocID"]==324]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==624]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==624]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==624]['PopTotal']

#names countries
popCountry = df[df["LocID"]==624]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1561]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1561]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1561]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1561]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==328]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==328]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==328]['PopTotal']

#names countries
popCountry = df[df["LocID"]==328]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==332]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==332]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==332]['PopTotal']

#names countries
popCountry = df[df["LocID"]==332]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1503]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1503]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1503]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1503]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==340]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==340]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==340]['PopTotal']

#names countries
popCountry = df[df["LocID"]==340]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==348]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==348]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==348]['PopTotal']

#names countries
popCountry = df[df["LocID"]==348]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==352]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==352]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==352]['PopTotal']

#names countries
popCountry = df[df["LocID"]==352]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==356]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==356]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==356]['PopTotal']

#names countries
popCountry = df[df["LocID"]==356]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==360]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==360]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==360]['PopTotal']

#names countries
popCountry = df[df["LocID"]==360]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==364]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==364]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==364]['PopTotal']

#names countries
popCountry = df[df["LocID"]==364]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==368]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==368]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==368]['PopTotal']

#names countries
popCountry = df[df["LocID"]==368]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==372]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==372]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==372]['PopTotal']

#names countries
popCountry = df[df["LocID"]==372]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==376]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==376]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==376]['PopTotal']

#names countries
popCountry = df[df["LocID"]==376]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==380]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==380]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==380]['PopTotal']

#names countries
popCountry = df[df["LocID"]==380]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==388]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==388]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==388]['PopTotal']

#names countries
popCountry = df[df["LocID"]==388]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==392]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==392]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==392]['PopTotal']

#names countries
popCountry = df[df["LocID"]==392]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==398]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==398]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==398]['PopTotal']

#names countries
popCountry = df[df["LocID"]==398]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==404]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==404]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==404]['PopTotal']

#names countries
popCountry = df[df["LocID"]==404]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==296]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==296]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==296]['PopTotal']

#names countries
popCountry = df[df["LocID"]==296]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==414]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==414]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==414]['PopTotal']

#names countries
popCountry = df[df["LocID"]==414]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==417]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==417]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==417]['PopTotal']

#names countries
popCountry = df[df["LocID"]==417]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2087]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2087]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2087]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2087]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2088]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2088]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2088]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2088]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2089]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2089]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2089]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2089]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2090]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2090]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2090]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2090]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1607]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1607]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1607]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1607]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1674]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1674]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1674]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1674]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1636]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1636]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1636]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1636]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==418]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==418]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==418]['PopTotal']

#names countries
popCountry = df[df["LocID"]==418]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==904]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==904]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==904]['PopTotal']

#names countries
popCountry = df[df["LocID"]==904]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1830]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1830]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1830]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1830]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1532]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1532]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1532]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1532]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1826]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1826]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1826]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1826]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==428]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==428]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==428]['PopTotal']

#names countries
popCountry = df[df["LocID"]==428]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1559]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1559]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1559]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1559]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==941]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==941]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==941]['PopTotal']

#names countries
popCountry = df[df["LocID"]==941]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1475]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1475]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1475]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1475]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1476]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1476]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1476]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1476]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1477]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1477]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1477]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1477]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1478]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1478]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1478]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1478]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==422]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==422]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==422]['PopTotal']

#names countries
popCountry = df[df["LocID"]==422]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==426]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==426]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==426]['PopTotal']

#names countries
popCountry = df[df["LocID"]==426]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==902]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==902]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==902]['PopTotal']

#names countries
popCountry = df[df["LocID"]==902]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==948]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==948]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==948]['PopTotal']

#names countries
popCountry = df[df["LocID"]==948]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==934]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==934]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==934]['PopTotal']

#names countries
popCountry = df[df["LocID"]==934]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1479]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1479]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1479]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1479]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1480]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1480]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1480]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1480]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1481]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1481]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1481]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1481]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1482]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1482]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1482]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1482]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==430]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==430]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==430]['PopTotal']

#names countries
popCountry = df[df["LocID"]==430]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==434]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==434]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==434]['PopTotal']

#names countries
popCountry = df[df["LocID"]==434]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==440]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==440]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==440]['PopTotal']

#names countries
popCountry = df[df["LocID"]==440]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1500]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1500]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1500]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1500]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1501]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1501]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1501]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1501]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==442]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==442]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==442]['PopTotal']

#names countries
popCountry = df[df["LocID"]==442]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==450]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==450]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==450]['PopTotal']

#names countries
popCountry = df[df["LocID"]==450]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==454]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==454]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==454]['PopTotal']

#names countries
popCountry = df[df["LocID"]==454]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==458]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==458]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==458]['PopTotal']

#names countries
popCountry = df[df["LocID"]==458]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==462]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==462]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==462]['PopTotal']

#names countries
popCountry = df[df["LocID"]==462]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==466]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==466]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==466]['PopTotal']

#names countries
popCountry = df[df["LocID"]==466]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==470]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==470]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==470]['PopTotal']

#names countries
popCountry = df[df["LocID"]==470]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==474]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==474]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==474]['PopTotal']

#names countries
popCountry = df[df["LocID"]==474]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==478]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==478]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==478]['PopTotal']

#names countries
popCountry = df[df["LocID"]==478]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==480]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==480]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==480]['PopTotal']

#names countries
popCountry = df[df["LocID"]==480]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==175]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==175]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==175]['PopTotal']

#names countries
popCountry = df[df["LocID"]==175]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==928]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==928]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==928]['PopTotal']

#names countries
popCountry = df[df["LocID"]==928]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==484]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==484]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==484]['PopTotal']

#names countries
popCountry = df[df["LocID"]==484]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==954]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==954]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==954]['PopTotal']

#names countries
popCountry = df[df["LocID"]==954]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==583]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==583]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==583]['PopTotal']

#names countries
popCountry = df[df["LocID"]==583]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==911]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==911]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==911]['PopTotal']

#names countries
popCountry = df[df["LocID"]==911]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1517]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1517]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1517]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1517]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==496]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==496]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==496]['PopTotal']

#names countries
popCountry = df[df["LocID"]==496]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==499]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==499]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==499]['PopTotal']

#names countries
popCountry = df[df["LocID"]==499]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==901]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==901]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==901]['PopTotal']

#names countries
popCountry = df[df["LocID"]==901]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1483]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1483]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1483]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1483]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1484]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1484]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1484]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1484]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1485]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1485]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1485]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1485]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1486]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1486]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1486]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1486]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==504]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==504]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==504]['PopTotal']

#names countries
popCountry = df[df["LocID"]==504]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==508]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==508]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==508]['PopTotal']

#names countries
popCountry = df[df["LocID"]==508]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==104]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==104]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==104]['PopTotal']

#names countries
popCountry = df[df["LocID"]==104]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==516]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==516]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==516]['PopTotal']

#names countries
popCountry = df[df["LocID"]==516]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==524]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==524]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==524]['PopTotal']

#names countries
popCountry = df[df["LocID"]==524]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==528]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==528]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==528]['PopTotal']

#names countries
popCountry = df[df["LocID"]==528]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1108]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1108]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1108]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1108]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==540]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==540]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==540]['PopTotal']

#names countries
popCountry = df[df["LocID"]==540]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1552]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1552]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1552]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1552]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==554]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==554]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==554]['PopTotal']

#names countries
popCountry = df[df["LocID"]==554]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1109]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1109]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1109]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1109]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==558]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==558]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==558]['PopTotal']

#names countries
popCountry = df[df["LocID"]==558]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==562]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==562]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==562]['PopTotal']

#names countries
popCountry = df[df["LocID"]==562]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==566]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==566]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==566]['PopTotal']

#names countries
popCountry = df[df["LocID"]==566]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1518]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1518]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1518]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1518]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1615]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1615]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1615]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1615]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1520]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1520]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1520]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1520]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1555]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1555]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1555]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1555]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==807]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==807]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==807]['PopTotal']

#names countries
popCountry = df[df["LocID"]==807]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==912]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==912]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==912]['PopTotal']

#names countries
popCountry = df[df["LocID"]==912]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1833]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1833]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1833]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1833]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==905]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==905]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==905]['PopTotal']

#names countries
popCountry = df[df["LocID"]==905]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==918]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==918]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==918]['PopTotal']

#names countries
popCountry = df[df["LocID"]==918]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==924]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==924]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==924]['PopTotal']

#names countries
popCountry = df[df["LocID"]==924]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==578]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==578]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==578]['PopTotal']

#names countries
popCountry = df[df["LocID"]==578]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==909]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==909]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==909]['PopTotal']

#names countries
popCountry = df[df["LocID"]==909]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1835]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1835]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1835]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1835]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==512]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==512]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==512]['PopTotal']

#names countries
popCountry = df[df["LocID"]==512]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1505]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1505]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1505]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1505]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2086]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2086]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2086]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2086]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2085]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2085]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2085]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2085]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1521]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1521]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1521]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1521]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1570]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1570]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1570]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1570]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==586]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==586]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==586]['PopTotal']

#names countries
popCountry = df[df["LocID"]==586]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==591]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==591]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==591]['PopTotal']

#names countries
popCountry = df[df["LocID"]==591]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==598]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==598]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==598]['PopTotal']

#names countries
popCountry = df[df["LocID"]==598]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==600]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==600]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==600]['PopTotal']

#names countries
popCountry = df[df["LocID"]==600]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==604]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==604]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==604]['PopTotal']

#names countries
popCountry = df[df["LocID"]==604]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==608]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==608]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==608]['PopTotal']

#names countries
popCountry = df[df["LocID"]==608]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==616]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==616]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==616]['PopTotal']

#names countries
popCountry = df[df["LocID"]==616]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==957]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==957]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==957]['PopTotal']

#names countries
popCountry = df[df["LocID"]==957]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==620]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==620]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==620]['PopTotal']

#names countries
popCountry = df[df["LocID"]==620]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==630]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==630]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==630]['PopTotal']

#names countries
popCountry = df[df["LocID"]==630]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==634]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==634]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==634]['PopTotal']

#names countries
popCountry = df[df["LocID"]==634]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==410]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==410]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==410]['PopTotal']

#names countries
popCountry = df[df["LocID"]==410]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==498]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==498]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==498]['PopTotal']

#names countries
popCountry = df[df["LocID"]==498]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==642]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==642]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==642]['PopTotal']

#names countries
popCountry = df[df["LocID"]==642]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==643]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==643]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==643]['PopTotal']

#names countries
popCountry = df[df["LocID"]==643]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==646]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==646]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==646]['PopTotal']

#names countries
popCountry = df[df["LocID"]==646]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==638]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==638]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==638]['PopTotal']

#names countries
popCountry = df[df["LocID"]==638]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2093]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2093]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2093]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2093]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2091]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2091]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2091]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2091]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2092]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2092]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2092]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2092]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==662]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==662]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==662]['PopTotal']

#names countries
popCountry = df[df["LocID"]==662]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==670]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==670]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==670]['PopTotal']

#names countries
popCountry = df[df["LocID"]==670]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==882]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==882]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==882]['PopTotal']

#names countries
popCountry = df[df["LocID"]==882]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==678]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==678]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==678]['PopTotal']

#names countries
popCountry = df[df["LocID"]==678]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==682]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==682]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==682]['PopTotal']

#names countries
popCountry = df[df["LocID"]==682]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==686]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==686]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==686]['PopTotal']

#names countries
popCountry = df[df["LocID"]==686]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==688]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==688]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==688]['PopTotal']

#names countries
popCountry = df[df["LocID"]==688]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==690]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==690]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==690]['PopTotal']

#names countries
popCountry = df[df["LocID"]==690]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2073]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2073]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2073]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2073]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==694]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==694]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==694]['PopTotal']

#names countries
popCountry = df[df["LocID"]==694]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==702]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==702]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==702]['PopTotal']

#names countries
popCountry = df[df["LocID"]==702]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==703]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==703]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==703]['PopTotal']

#names countries
popCountry = df[df["LocID"]==703]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==705]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==705]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==705]['PopTotal']

#names countries
popCountry = df[df["LocID"]==705]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1637]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1637]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1637]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1637]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==90]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==90]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==90]['PopTotal']

#names countries
popCountry = df[df["LocID"]==90]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==706]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==706]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==706]['PopTotal']

#names countries
popCountry = df[df["LocID"]==706]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==710]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==710]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==710]['PopTotal']

#names countries
popCountry = df[df["LocID"]==710]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==931]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==931]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==931]['PopTotal']

#names countries
popCountry = df[df["LocID"]==931]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1321]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1321]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1321]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1321]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==728]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==728]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==728]['PopTotal']

#names countries
popCountry = df[df["LocID"]==728]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==920]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==920]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==920]['PopTotal']

#names countries
popCountry = df[df["LocID"]==920]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==913]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==913]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==913]['PopTotal']

#names countries
popCountry = df[df["LocID"]==913]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1564]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1564]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1564]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1564]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==5501]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==5501]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==5501]['PopTotal']

#names countries
popCountry = df[df["LocID"]==5501]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1534]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1534]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1534]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1534]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==925]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==925]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==925]['PopTotal']

#names countries
popCountry = df[df["LocID"]==925]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==724]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==724]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==724]['PopTotal']

#names countries
popCountry = df[df["LocID"]==724]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==144]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==144]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==144]['PopTotal']

#names countries
popCountry = df[df["LocID"]==144]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==275]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==275]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==275]['PopTotal']

#names countries
popCountry = df[df["LocID"]==275]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==947]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==947]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==947]['PopTotal']

#names countries
popCountry = df[df["LocID"]==947]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==729]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==729]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==729]['PopTotal']

#names countries
popCountry = df[df["LocID"]==729]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==740]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==740]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==740]['PopTotal']

#names countries
popCountry = df[df["LocID"]==740]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==752]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==752]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==752]['PopTotal']

#names countries
popCountry = df[df["LocID"]==752]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==756]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==756]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==756]['PopTotal']

#names countries
popCountry = df[df["LocID"]==756]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==760]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==760]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==760]['PopTotal']

#names countries
popCountry = df[df["LocID"]==760]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==762]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==762]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==762]['PopTotal']

#names countries
popCountry = df[df["LocID"]==762]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==764]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==764]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==764]['PopTotal']

#names countries
popCountry = df[df["LocID"]==764]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==626]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==626]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==626]['PopTotal']

#names countries
popCountry = df[df["LocID"]==626]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==768]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==768]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==768]['PopTotal']

#names countries
popCountry = df[df["LocID"]==768]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==776]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==776]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==776]['PopTotal']

#names countries
popCountry = df[df["LocID"]==776]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==780]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==780]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==780]['PopTotal']

#names countries
popCountry = df[df["LocID"]==780]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==788]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==788]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==788]['PopTotal']

#names countries
popCountry = df[df["LocID"]==788]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==792]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==792]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==792]['PopTotal']

#names countries
popCountry = df[df["LocID"]==792]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==795]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==795]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==795]['PopTotal']

#names countries
popCountry = df[df["LocID"]==795]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1735]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1735]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1735]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1735]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1819]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1819]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1819]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1819]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1611]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1611]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1611]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1611]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1610]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1610]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1610]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1610]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1703]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1703]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1703]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1703]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1612]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1612]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1612]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1612]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1613]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1613]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1613]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1613]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1704]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1704]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1704]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1704]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1818]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1818]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1818]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1818]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1586]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1586]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1586]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1586]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2042]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2042]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2042]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2042]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1587]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1587]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1587]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1587]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1585]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1585]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1585]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1585]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2041]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2041]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2041]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2041]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1589]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1589]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1589]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1589]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1590]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1590]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1590]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1590]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1591]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1591]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1591]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1591]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
##Population male:
popMale = df[df["LocID"]==1592]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1592]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1592]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1592]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2035]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2035]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2035]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2035]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2036]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2036]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2036]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2036]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2034]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2034]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2034]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2034]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2039]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2039]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2039]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2039]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2029]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2029]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2029]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2029]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2031]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2031]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2031]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2031]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2037]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2037]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2037]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2037]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2032]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2032]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2032]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2032]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2038]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2038]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2038]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2038]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2033]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2033]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2033]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2033]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2040]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2040]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2040]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2040]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==2030]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==2030]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==2030]['PopTotal']

#names countries
popCountry = df[df["LocID"]==2030]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1822]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1822]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1822]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1822]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==800]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==800]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==800]['PopTotal']

#names countries
popCountry = df[df["LocID"]==800]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==804]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==804]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==804]['PopTotal']

#names countries
popCountry = df[df["LocID"]==804]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==784]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==784]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==784]['PopTotal']

#names countries
popCountry = df[df["LocID"]==784]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==826]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==826]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==826]['PopTotal']

#names countries
popCountry = df[df["LocID"]==826]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1110]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1110]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1110]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1110]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1730]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1730]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1730]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1730]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1745]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1745]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1745]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1745]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1760]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1760]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1760]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1760]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==834]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==834]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==834]['PopTotal']

#names countries
popCountry = df[df["LocID"]==834]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==850]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==850]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==850]['PopTotal']

#names countries
popCountry = df[df["LocID"]==850]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==840]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==840]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==840]['PopTotal']

#names countries
popCountry = df[df["LocID"]==840]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1111]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1111]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1111]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1111]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1502]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1502]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1502]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1502]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==858]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==858]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==858]['PopTotal']

#names countries
popCountry = df[df["LocID"]==858]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==860]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==860]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==860]['PopTotal']

#names countries
popCountry = df[df["LocID"]==860]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==548]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==548]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==548]['PopTotal']

#names countries
popCountry = df[df["LocID"]==548]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==862]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==862]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==862]['PopTotal']

#names countries
popCountry = df[df["LocID"]==862]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==704]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==704]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==704]['PopTotal']

#names countries
popCountry = df[df["LocID"]==704]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1509]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1509]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1509]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1509]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1510]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1510]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1510]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1510]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1511]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1511]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1511]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1511]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1512]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1512]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1512]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1512]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1513]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1513]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1513]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1513]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1508]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1508]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1508]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1508]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1820]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1820]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1820]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1820]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1593]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1593]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1593]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1593]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1596]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1596]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1596]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1596]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1595]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1595]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1595]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1595]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1594]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1594]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1594]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1594]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1597]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1597]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1597]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1597]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1598]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1598]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1598]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1598]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1543]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1543]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1543]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1543]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==914]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==914]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==914]['PopTotal']

#names countries
popCountry = df[df["LocID"]==914]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==922]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==922]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==922]['PopTotal']

#names countries
popCountry = df[df["LocID"]==922]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==926]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==926]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==926]['PopTotal']

#names countries
popCountry = df[df["LocID"]==926]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1827]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1827]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1827]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1827]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==732]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==732]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==732]['PopTotal']

#names countries
popCountry = df[df["LocID"]==732]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==900]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==900]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==900]['PopTotal']

#names countries
popCountry = df[df["LocID"]==900]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==1801]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==1801]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==1801]['PopTotal']

#names countries
popCountry = df[df["LocID"]==1801]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==887]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==887]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==887]['PopTotal']

#names countries
popCountry = df[df["LocID"]==887]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==894]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==894]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==894]['PopTotal']

#names countries
popCountry = df[df["LocID"]==894]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)

# %%
#Population male:
popMale = df[df["LocID"]==716]["PopMale"]

#Population female:
popFemale = df[df["LocID"]==716]["PopFemale"]

#population mondiale:
popMondiale = df[df['LocID']==716]['PopTotal']

#names countries
popCountry = df[df["LocID"]==716]["Location"].unique()

#graph de la population
calPopMaleFemale(popMale, popFemale, popCountry, popMondiale)
